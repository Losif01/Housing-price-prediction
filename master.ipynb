# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df_train = pd.read_csv("train.csv")
df_train.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
df_train.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %%
for i in df_train.columns:
    print(f" Column name: {i} \n-Unique values in that column: {df_train[i].nunique()} \n--na values: {df_train[i].isna().sum()} \n")
     
#if (df_train.isna().sum())
# Out:
#  Column name: Id
# -Unique values in that column: 1460
# --na values: 0
#
#  Column name: MSSubClass
# -Unique values in that column: 15
# --na values: 0
#
#  Column name: MSZoning
# -Unique values in that column: 5
# --na values: 0
#
#  Column name: LotFrontage
# -Unique values in that column: 110
# --na values: 259
#
#  Column name: LotArea
# -Unique values in that column: 1073
# --na values: 0
#
#  Column name: Street
# -Unique values in that column: 2
# --na values: 0
#
#  Column name: Alley
# -Unique values in that column: 2
# --na values: 1369
#
#  Column name: LotShape
# -Unique values in that column: 4
# --na values: 0
#
#  Column name: LandContour
# -Unique values in that column: 4
# --na values: 0
#
#  Column name: Utilities
# -Unique values in that column: 2
# --na values: 0
#
#  Column name: LotConfig
# -Unique values in that column: 5
# --na values: 0
#
#  Column name: LandSlope
# -Unique values in that column: 3
# --na values: 0
#
#  Column name: Neighborhood
# ...

# %%
print(df_train.shape)
df_test = pd.read_csv("test.csv")
df_test.shape
# Out:
# (1460, 81)
# (1459, 80)

# %%
def nuls_list(df):
    nuls_list = []
    for i in df.columns:
        if df[i].isna().sum() > 0:
            nuls_list.append((i , df[i].isna().sum()/1460))
    return nuls_list

# %%
all_nuls = (nuls_list(df_train))
all_nuls
# Out:
# [('LotFrontage', 0.1773972602739726),
#  ('Alley', 0.9376712328767123),
#  ('MasVnrType', 0.5972602739726027),
#  ('MasVnrArea', 0.005479452054794521),
#  ('BsmtQual', 0.025342465753424658),
#  ('BsmtCond', 0.025342465753424658),
#  ('BsmtExposure', 0.026027397260273973),
#  ('BsmtFinType1', 0.025342465753424658),
#  ('BsmtFinType2', 0.026027397260273973),
#  ('Electrical', 0.0006849315068493151),
#  ('FireplaceQu', 0.4726027397260274),
#  ('GarageType', 0.05547945205479452),
#  ('GarageYrBlt', 0.05547945205479452),
#  ('GarageFinish', 0.05547945205479452),
#  ('GarageQual', 0.05547945205479452),
#  ('GarageCond', 0.05547945205479452),
#  ('PoolQC', 0.9952054794520548),
#  ('Fence', 0.8075342465753425),
#  ('MiscFeature', 0.963013698630137)]

# %%
sorted_htl = (sorted(all_nuls, key= lambda x: x[1] , reverse = True))

for i in sorted_htl:
    print(i)
# Out:
# ('PoolQC', 0.9952054794520548)
# ('MiscFeature', 0.963013698630137)
# ('Alley', 0.9376712328767123)
# ('Fence', 0.8075342465753425)
# ('MasVnrType', 0.5972602739726027)
# ('FireplaceQu', 0.4726027397260274)
# ('LotFrontage', 0.1773972602739726)
# ('GarageType', 0.05547945205479452)
# ('GarageYrBlt', 0.05547945205479452)
# ('GarageFinish', 0.05547945205479452)
# ('GarageQual', 0.05547945205479452)
# ('GarageCond', 0.05547945205479452)
# ('BsmtExposure', 0.026027397260273973)
# ('BsmtFinType2', 0.026027397260273973)
# ('BsmtQual', 0.025342465753424658)
# ('BsmtCond', 0.025342465753424658)
# ('BsmtFinType1', 0.025342465753424658)
# ('MasVnrArea', 0.005479452054794521)
# ('Electrical', 0.0006849315068493151)

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
df_train["SalePrice"].describe()
# Out:
# count      1460.000000
# mean     180921.195890
# std       79442.502883
# min       34900.000000
# 25%      129975.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64

# %% [markdown]
# ### Since SalesPrice is a number, we will work with regression

# %%
import seaborn as sns
sns.set(style="whitegrid");

sns.distplot(df_train["SalePrice"] , bins = 50 , color= "green")
# Out:
# C:\Users\losif\AppData\Local\Temp\ipykernel_43712\4177935596.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_train["SalePrice"] , bins = 50 , color= "green")
# <Axes: xlabel='SalePrice', ylabel='Density'>

# %%
df_num = df_train.select_dtypes(include = [np.number])
df_num.head()
# Out:
#    Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0   1          60         65.0     8450            7            5       2003
# 1   2          20         80.0     9600            6            8       1976
# 2   3          60         68.0    11250            7            5       2001
# 3   4          70         60.0     9550            7            5       1915
# 4   5          60         84.0    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  ...  WoodDeckSF  OpenPorchSF  \
# 0          2003       196.0         706  ...           0           61
# 1          1976         0.0         978  ...         298            0
# 2          2002       162.0         486  ...           0           42
# 3          1970         0.0         216  ...           0           35
# 4          2000       350.0         655  ...         192           84
#
#    EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  MiscVal  MoSold  YrSold  \
# ...

# %%
df_num.corr()
# Out:
#                      Id  MSSubClass  LotFrontage   LotArea  OverallQual  \
# Id             1.000000    0.011156    -0.010601 -0.033226    -0.028365
# MSSubClass     0.011156    1.000000    -0.386347 -0.139781     0.032628
# LotFrontage   -0.010601   -0.386347     1.000000  0.426095     0.251646
# LotArea       -0.033226   -0.139781     0.426095  1.000000     0.105806
# OverallQual   -0.028365    0.032628     0.251646  0.105806     1.000000
# OverallCond    0.012609   -0.059316    -0.059213 -0.005636    -0.091932
# YearBuilt     -0.012713    0.027850     0.123349  0.014228     0.572323
# YearRemodAdd  -0.021998    0.040581     0.088866  0.013788     0.550684
# MasVnrArea    -0.050298    0.022936     0.193458  0.104160     0.411876
# BsmtFinSF1    -0.005024   -0.069836     0.233633  0.214103     0.239666
# BsmtFinSF2    -0.005968   -0.065649     0.049900  0.111170    -0.059119
# BsmtUnfSF     -0.007940   -0.140759     0.132644 -0.002618     0.308159
# ...

# %%
df_num.hist(figsize=(16, 20), bins=50, xlabelsize=8, ylabelsize=8)
# Out:
# array([[<Axes: title={'center': 'Id'}>,
#         <Axes: title={'center': 'MSSubClass'}>,
#         <Axes: title={'center': 'LotFrontage'}>,
#         <Axes: title={'center': 'LotArea'}>,
#         <Axes: title={'center': 'OverallQual'}>,
#         <Axes: title={'center': 'OverallCond'}>],
#        [<Axes: title={'center': 'YearBuilt'}>,
#         <Axes: title={'center': 'YearRemodAdd'}>,
#         <Axes: title={'center': 'MasVnrArea'}>,
#         <Axes: title={'center': 'BsmtFinSF1'}>,
#         <Axes: title={'center': 'BsmtFinSF2'}>,
#         <Axes: title={'center': 'BsmtUnfSF'}>],
#        [<Axes: title={'center': 'TotalBsmtSF'}>,
#         <Axes: title={'center': '1stFlrSF'}>,
#         <Axes: title={'center': '2ndFlrSF'}>,
#         <Axes: title={'center': 'LowQualFinSF'}>,
#         <Axes: title={'center': 'GrLivArea'}>,
#         <Axes: title={'center': 'BsmtFullBath'}>],
#        [<Axes: title={'center': 'BsmtHalfBath'}>,
#         <Axes: title={'center': 'FullBath'}>,
# ...

# %%
#df_num.corr()["SalePrice"].sort_values(ascending=False)

sns.heatmap(df_num.corr())
# Out:
# <Axes: >

# %%
nums_correlation_sorted_h2l = df_num.corr()["SalePrice"].sort_values(ascending=False)
nums_correlation_sorted_h2l
# Out:
# SalePrice        1.000000
# OverallQual      0.790982
# GrLivArea        0.708624
# GarageCars       0.640409
# GarageArea       0.623431
# TotalBsmtSF      0.613581
# 1stFlrSF         0.605852
# FullBath         0.560664
# TotRmsAbvGrd     0.533723
# YearBuilt        0.522897
# YearRemodAdd     0.507101
# GarageYrBlt      0.486362
# MasVnrArea       0.477493
# Fireplaces       0.466929
# BsmtFinSF1       0.386420
# LotFrontage      0.351799
# WoodDeckSF       0.324413
# 2ndFlrSF         0.319334
# OpenPorchSF      0.315856
# HalfBath         0.284108
# LotArea          0.263843
# BsmtFullBath     0.227122
# BsmtUnfSF        0.214479
# BedroomAbvGr     0.168213
# ScreenPorch      0.111447
# PoolArea         0.092404
# MoSold           0.046432
# 3SsnPorch        0.044584
# BsmtFinSF2      -0.011378
# BsmtHalfBath    -0.016844
# MiscVal         -0.021190
# Id              -0.021917
# LowQualFinSF    -0.025606
# YrSold          -0.028923
# OverallCond     -0.077856
# ...

# %%
missing_values = df_train.isnull().sum().sort_values(ascending=False)

missing_values = missing_values[missing_values > 0]
missing_values = missing_values / len(df_train)
#! PoolQC, MiscFeature, Alley, Fence,
missing_values
print(len(missing_values))
# Out:
# 19

# %%
missing_values_test = df_test.isnull().sum().sort_values(ascending=False)
missing_values_test = missing_values_test[missing_values_test > 0] 
missing_values_test = missing_values_test / len(df_test)
missing_values_test
print(len(missing_values_test))
# Out:
# 33

# %%
#sns.distplot(df_train["LotFrontage"])
#sns.distplot(df_train["MasVnrArea"])
sns.distplot(df_train["GarageYrBlt"])
# Out:
# C:\Users\losif\AppData\Local\Temp\ipykernel_43712\3988112888.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_train["GarageYrBlt"])
# <Axes: xlabel='GarageYrBlt', ylabel='Density'>

# %%
df_train["LotFrontage"].fillna(df_train["LotFrontage"].mean(), inplace = True)
df_test["LotFrontage"].fillna(df_test["LotFrontage"].mean(), inplace = True)
# Out:
# C:\Users\losif\AppData\Local\Temp\ipykernel_43712\3032606156.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_train["LotFrontage"].fillna(df_train["LotFrontage"].mean(), inplace = True)
# C:\Users\losif\AppData\Local\Temp\ipykernel_43712\3032606156.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
df_train["MasVnrArea"].fillna(df_train["MasVnrArea"].min(), inplace = True)
df_test["MasVnrArea"].fillna(df_test["MasVnrArea"].min(), inplace = True)
# Out:
# C:\Users\losif\AppData\Local\Temp\ipykernel_43712\2408750665.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_train["MasVnrArea"].fillna(df_train["MasVnrArea"].min(), inplace = True)
# C:\Users\losif\AppData\Local\Temp\ipykernel_43712\2408750665.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
df_train["GarageYrBlt"].fillna(df_train["GarageYrBlt"].median(), inplace = True)
df_test["GarageYrBlt"].fillna(df_test["GarageYrBlt"].median(), inplace = True)
# Out:
# C:\Users\losif\AppData\Local\Temp\ipykernel_43712\1459759920.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_train["GarageYrBlt"].fillna(df_train["GarageYrBlt"].median(), inplace = True)
# C:\Users\losif\AppData\Local\Temp\ipykernel_43712\1459759920.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
# Fill missing Basement-related numeric values with 0
for col in ['BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'BsmtFullBath', 'BsmtHalfBath']:
    df_train[col] = df_train[col].fillna(0)
    df_test[col] = df_test[col].fillna(0)

# Fill missing numeric Garage features with 0
df_train['GarageCars'] = df_train['GarageCars'].fillna(0)
df_test['GarageCars'] = df_test['GarageCars'].fillna(0)

df_train['GarageArea'] = df_train['GarageArea'].fillna(0)
df_test['GarageArea'] = df_test['GarageArea'].fillna(0)

# %%
missing_values_test = df_test.isnull().sum().sort_values(ascending=False)
missing_values_test = missing_values_test[missing_values_test > 0] 
missing_values_test = missing_values_test / len(df_test)
missing_values_test.__len__()
# Out:
# 22

# %%
missing_values = df_train.isnull().sum().sort_values(ascending=False)
missing_values = missing_values[missing_values > 0] 
missing_values = missing_values / len(df_test)
missing_values.__len__()
# Out:
# 16

# %%
print(missing_values)
# Out:
# PoolQC          0.995888
# MiscFeature     0.963674
# Alley           0.938314
# Fence           0.808088
# MasVnrType      0.597670
# FireplaceQu     0.472927
# GarageType      0.055517
# GarageQual      0.055517
# GarageCond      0.055517
# GarageFinish    0.055517
# BsmtExposure    0.026045
# BsmtFinType2    0.026045
# BsmtFinType1    0.025360
# BsmtCond        0.025360
# BsmtQual        0.025360
# Electrical      0.000685
# dtype: float64

# %%
print(missing_values_test)
# Out:
# PoolQC          0.997944
# MiscFeature     0.965045
# Alley           0.926662
# Fence           0.801234
# MasVnrType      0.612748
# FireplaceQu     0.500343
# GarageFinish    0.053461
# GarageCond      0.053461
# GarageQual      0.053461
# GarageType      0.052090
# BsmtCond        0.030843
# BsmtExposure    0.030158
# BsmtQual        0.030158
# BsmtFinType2    0.028787
# BsmtFinType1    0.028787
# MSZoning        0.002742
# Utilities       0.001371
# Functional      0.001371
# SaleType        0.000685
# Exterior2nd     0.000685
# KitchenQual     0.000685
# Exterior1st     0.000685
# dtype: float64

# %%
df_train.drop(['PoolQC', 'MiscFeature', 'Alley', 'Fence', 'MasVnrType'], axis=1, inplace=True)   
df_test.drop(['PoolQC', 'MiscFeature', 'Alley', 'Fence', 'MasVnrType'], axis=1, inplace=True)

# %%
df_train
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape  \
# 0        1          60       RL         65.0     8450   Pave      Reg
# 1        2          20       RL         80.0     9600   Pave      Reg
# 2        3          60       RL         68.0    11250   Pave      IR1
# 3        4          70       RL         60.0     9550   Pave      IR1
# 4        5          60       RL         84.0    14260   Pave      IR1
# ...    ...         ...      ...          ...      ...    ...      ...
# 1455  1456          60       RL         62.0     7917   Pave      Reg
# 1456  1457          20       RL         85.0    13175   Pave      Reg
# 1457  1458          70       RL         66.0     9042   Pave      Reg
# 1458  1459          20       RL         68.0     9717   Pave      Reg
# 1459  1460          20       RL         75.0     9937   Pave      Reg
#
#      LandContour Utilities LotConfig  ... EnclosedPorch 3SsnPorch ScreenPorch  \
# ...

# %%
df_test
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape  \
# 0     1461          20       RH         80.0    11622   Pave      Reg
# 1     1462          20       RL         81.0    14267   Pave      IR1
# 2     1463          60       RL         74.0    13830   Pave      IR1
# 3     1464          60       RL         78.0     9978   Pave      IR1
# 4     1465         120       RL         43.0     5005   Pave      IR1
# ...    ...         ...      ...          ...      ...    ...      ...
# 1454  2915         160       RM         21.0     1936   Pave      Reg
# 1455  2916         160       RM         21.0     1894   Pave      Reg
# 1456  2917          20       RL        160.0    20000   Pave      Reg
# 1457  2918          85       RL         62.0    10441   Pave      Reg
# 1458  2919          60       RL         74.0     9627   Pave      Reg
#
#      LandContour Utilities LotConfig  ... OpenPorchSF EnclosedPorch 3SsnPorch  \
# ...

# %%
def getMissingValues(df):
    missing_values = df.isnull().sum().sort_values(ascending=False)
    missing_values = missing_values[missing_values > 0]
    missing_values = missing_values / len(df)
    return [missing_values], missing_values.__len__()

# %%
print(getMissingValues(df_train))
print(getMissingValues(df_test))
# Out:
# ([FireplaceQu     0.472603
# GarageType      0.055479
# GarageCond      0.055479
# GarageFinish    0.055479
# GarageQual      0.055479
# BsmtFinType2    0.026027
# BsmtExposure    0.026027
# BsmtFinType1    0.025342
# BsmtCond        0.025342
# BsmtQual        0.025342
# Electrical      0.000685
# dtype: float64], 11)
# ([FireplaceQu     0.500343
# GarageCond      0.053461
# GarageFinish    0.053461
# GarageQual      0.053461
# GarageType      0.052090
# BsmtCond        0.030843
# BsmtQual        0.030158
# BsmtExposure    0.030158
# BsmtFinType2    0.028787
# BsmtFinType1    0.028787
# MSZoning        0.002742
# Utilities       0.001371
# Functional      0.001371
# Exterior2nd     0.000685
# Exterior1st     0.000685
# KitchenQual     0.000685
# SaleType        0.000685
# dtype: float64], 17)

# %%
def getUniqueVaules(df):
    unique_values = []
    for i in df.columns:
        unique_values.append((i , df[i].nunique()))
    return f" {unique_values} "

getUniqueVaules(df_train[["BsmtCond", "BsmtQual", "BsmtExposure", "BsmtFinType1", "BsmtFinType2"]])
# Out:
# " [('BsmtCond', 4), ('BsmtQual', 4), ('BsmtExposure', 4), ('BsmtFinType1', 6), ('BsmtFinType2', 6)] "

# %%
getUniqueVaules(df_test[["BsmtCond", "BsmtQual", "BsmtExposure", "BsmtFinType1", "BsmtFinType2"]])
# Out:
# " [('BsmtCond', 4), ('BsmtQual', 4), ('BsmtExposure', 4), ('BsmtFinType1', 6), ('BsmtFinType2', 6)] "

# %%
df_train[["BsmtCond", "BsmtQual", "BsmtExposure", "BsmtFinType1", "BsmtFinType2"]]
# Bsmt_count = df_train.groupby(["BsmtCond", "BsmtQual", "BsmtExposure", "BsmtFinType1", "BsmtFinType2"]).size()

# Bsmtcond=(Bsmt_count)

from collections import Counter

Bsmtcond=(dict(Counter(df_train["BsmtCond"])))
Bsmtqual=(dict(Counter(df_train["BsmtQual"])))
Bsmtxp=(dict(Counter(df_train["BsmtExposure"])))
Bsmtt1=(dict(Counter(df_train["BsmtFinType1"])))
Bsmtt2=(dict(Counter(df_train["BsmtFinType2"])))

# %%
import matplotlib.pyplot as plt
import numpy as np

def plotBsmt(data):
    # Separate the dictionary keys and values
    keys = list(data.keys())
    values = list(data.values())

# Plot the bar histogram
    plt.figure(figsize=(10, 6))
    plt.bar(range(len(data)), values, tick_label=keys)

# Add title and labels
    plt.title('Bar Histogram of Dictionary Data')
    plt.xlabel('Keys')
    plt.ylabel('Values')

    # Display the plot
    plt.show()

# %%
plotBsmt(Bsmtcond) # fill with TA
plotBsmt(Bsmtqual) # fill randomly with Gd and TA
plotBsmt(Bsmtxp)   # fill with No
plotBsmt(Bsmtt1)   # fill randomly with controlled probabilities
plotBsmt(Bsmtt2)   # fill with Unf

# %%
from sklearn.preprocessing import OneHotEncoder , LabelEncoder

# %%
Bsmtt1_list = [i for i in Bsmtt1.values()]
Bsmtt1_list  
Bsmtt1_list = np.array(Bsmtt1_list)
Bsmtt1_probability_vector = Bsmtt1_list / sum(Bsmtt1_list)
print(Bsmtt1_probability_vector)
# Out:
# [0.28630137 0.15068493 0.29452055 0.09109589 0.10136986 0.02534247
#  0.05068493]

# %%
print(Bsmtt1)
# Out:
# {'GLQ': 418, 'ALQ': 220, 'Unf': 430, 'Rec': 133, 'BLQ': 148, nan: 37, 'LwQ': 74}

# %%
# plotBsmt(Bsmtcond) #? fill with TA
# plotBsmt(Bsmtqual) #? fill randomly with Gd and TA
# plotBsmt(Bsmtxp)   #? fill with No
# plotBsmt(Bsmtt1)   #? fill randomly with controlled probabilities
# plotBsmt(Bsmtt2)   #? fill with Unf


df_train["BsmtCond"].fillna("TA", inplace = True)
df_test["BsmtCond"].fillna("TA", inplace = True)

df_train["BsmtQual"].fillna(np.random.choice(["Gd", "TA"]), inplace = True)
df_test["BsmtQual"].fillna(np.random.choice(["Gd", "TA"]), inplace = True)

df_train["BsmtExposure"].fillna("No", inplace = True)
df_test["BsmtExposure"].fillna("No", inplace = True)

df_train["BsmtFinType1"].fillna(np.random.choice(["GLQ", "Unf", "ALQ", "BLQ", "Rec", "LwQ"], p = [0.28630137, 0.15068493, 0.29452055, 0.09109589, 0.10136986, 0.05068493+0.02534247]), inplace = True)
df_test["BsmtFinType1"].fillna(np.random.choice(["GLQ", "Unf", "ALQ", "BLQ", "Rec", "LwQ"], p = [0.28630137, 0.15068493, 0.29452055, 0.09109589, 0.10136986, 0.05068493+0.02534247] ), inplace = True)

df_train["BsmtFinType2"].fillna("Unf", inplace = True)
df_test["BsmtFinType2"].fillna("Unf", inplace = True)
# Out:
# C:\Users\losif\AppData\Local\Temp\ipykernel_43712\348265351.py:8: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_train["BsmtCond"].fillna("TA", inplace = True)
# C:\Users\losif\AppData\Local\Temp\ipykernel_43712\348265351.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
#df_train[["BsmtCond", "BsmtQual", "BsmtExposure", "BsmtFinType1", "BsmtFinType2"]]
# Bsmt_count = df_train.groupby(["BsmtCond", "BsmtQual", "BsmtExposure", "BsmtFinType1", "BsmtFinType2"]).size()

# Bsmtcond=(Bsmt_count)

from collections import Counter

Bsmtcond=(dict(Counter(df_train["BsmtCond"])))
Bsmtqual=(dict(Counter(df_train["BsmtQual"])))
Bsmtxp=(dict(Counter(df_train["BsmtExposure"])))
Bsmtt1=(dict(Counter(df_train["BsmtFinType1"])))
Bsmtt2=(dict(Counter(df_train["BsmtFinType2"])))

# %%
plotBsmt(Bsmtcond) # fill with TA
plotBsmt(Bsmtqual) # fill randomly with Gd and TA
plotBsmt(Bsmtxp)   # fill with No
plotBsmt(Bsmtt1)   # fill randomly with controlled probabilities
plotBsmt(Bsmtt2)   # fill with Unf

# %%
print(getMissingValues(df_train))
print(getMissingValues(df_test))
# Out:
# ([FireplaceQu     0.472603
# GarageType      0.055479
# GarageFinish    0.055479
# GarageQual      0.055479
# GarageCond      0.055479
# Electrical      0.000685
# dtype: float64], 6)
# ([FireplaceQu     0.500343
# GarageFinish    0.053461
# GarageQual      0.053461
# GarageCond      0.053461
# GarageType      0.052090
# MSZoning        0.002742
# Functional      0.001371
# Utilities       0.001371
# Exterior2nd     0.000685
# KitchenQual     0.000685
# Exterior1st     0.000685
# SaleType        0.000685
# dtype: float64], 12)

# %%
df_train[["FireplaceQu", "GarageType", "GarageFinish", "GarageQual", "GarageCond", "Electrical"]]
# Out:
#      FireplaceQu GarageType GarageFinish GarageQual GarageCond Electrical
# 0            NaN     Attchd          RFn         TA         TA      SBrkr
# 1             TA     Attchd          RFn         TA         TA      SBrkr
# 2             TA     Attchd          RFn         TA         TA      SBrkr
# 3             Gd     Detchd          Unf         TA         TA      SBrkr
# 4             TA     Attchd          RFn         TA         TA      SBrkr
# ...          ...        ...          ...        ...        ...        ...
# 1455          TA     Attchd          RFn         TA         TA      SBrkr
# 1456          TA     Attchd          Unf         TA         TA      SBrkr
# 1457          Gd     Attchd          RFn         TA         TA      SBrkr
# 1458         NaN     Attchd          Unf         TA         TA      FuseA
# 1459         NaN     Attchd          Fin         TA         TA      SBrkr
#
# [1460 rows x 6 columns]

# %%
df_test[["FireplaceQu", "GarageType", "GarageFinish", "GarageQual", "GarageCond", "MSZoning", "Functional", "Utilities", "SaleType", "KitchenQual", "Exterior2nd", "Exterior1st"]]
# Out:
#      FireplaceQu GarageType GarageFinish GarageQual GarageCond MSZoning  \
# 0            NaN     Attchd          Unf         TA         TA       RH
# 1            NaN     Attchd          Unf         TA         TA       RL
# 2             TA     Attchd          Fin         TA         TA       RL
# 3             Gd     Attchd          Fin         TA         TA       RL
# 4            NaN     Attchd          RFn         TA         TA       RL
# ...          ...        ...          ...        ...        ...      ...
# 1454         NaN        NaN          NaN        NaN        NaN       RM
# 1455         NaN    CarPort          Unf         TA         TA       RM
# 1456          TA     Detchd          Unf         TA         TA       RL
# 1457         NaN        NaN          NaN        NaN        NaN       RL
# 1458          TA     Attchd          Fin         TA         TA       RL
#
#      Functional Utilities SaleType KitchenQual Exterior2nd Exterior1st
# ...

# %%
# Assuming df_test is your DataFrame
columns_to_plot = ["FireplaceQu", "GarageType", "GarageFinish", "GarageQual", "GarageCond", "MSZoning", 
                   "Functional", "Utilities", "SaleType", "KitchenQual", "Exterior2nd", "Exterior1st"]

# Set the size of the figure
plt.figure(figsize=(20, 15))

# Loop through the columns and create a count plot for each
for i, column in enumerate(columns_to_plot, 1):
    plt.subplot(4, 3, i)  # Adjust the layout: 4 rows and 3 columns
    sns.countplot(data=df_test, x=column)
    plt.title(f'Frequency of {column}')
    plt.xticks(rotation=90)  # Rotate the x-axis labels for better readability

plt.tight_layout()  # Adjust subplots to fit into the figure area.
plt.show()

# %%
# Assuming df_test is your DataFrame
columns_to_plot = ["FireplaceQu", "GarageType", "GarageFinish", "GarageQual", "GarageCond", "Electrical"]

# Set the size of the figure
plt.figure(figsize=(20, 15))

# Loop through the columns and create a count plot for each
for i, column in enumerate(columns_to_plot, 1):
    plt.subplot(4, 3, i)  # Adjust the layout: 4 rows and 3 columns
    sns.countplot(data=df_test, x=column)
    plt.title(f'Frequency of {column}')
    plt.xticks(rotation=90)  # Rotate the x-axis labels for better readability

plt.tight_layout()  # Adjust subplots to fit into the figure area.
plt.show()

# %%
df_test.drop(["Utilities"], axis = 1, inplace = True)
df_train.drop(["Utilities"], axis = 1, inplace = True)

# %%
print(df_train.shape)
print(df_test.shape)
# Out:
# (1460, 75)
# (1459, 74)

# %%
#????????????????????? FireplaceQu
# GarageType
# GarageFinish
# GarageQual
# GarageCond
# MSZoning
# Functional
#? Utilities
# SaleType
# KitchenQual
# Exterior2nd
# Exterior1st

# %%
df_test["FireplaceQu"].fillna("Unknown", inplace = True)
df_train["FireplaceQu"].fillna("Unknown", inplace = True)
# Out:
# C:\Users\losif\AppData\Local\Temp\ipykernel_43712\152437202.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_test["FireplaceQu"].fillna("Unknown", inplace = True)
# C:\Users\losif\AppData\Local\Temp\ipykernel_43712\152437202.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
for column in ["GarageType", "GarageFinish", "GarageQual", "GarageCond", "MSZoning", "Functional", "SaleType", "KitchenQual", "Exterior2nd", "Exterior1st"]:
    df_train[column].fillna(df_train[column].mode()[0], inplace=True)
# Out:
# C:\Users\losif\AppData\Local\Temp\ipykernel_43712\578698544.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_train[column].fillna(df_train[column].mode()[0], inplace=True)

# %%
for column in ["GarageType", "GarageFinish", "GarageQual", "GarageCond", "MSZoning", "Functional", "SaleType", "KitchenQual", "Exterior2nd", "Exterior1st"]:
    df_test[column].fillna(df_test[column].mode()[0], inplace=True)
# Out:
# C:\Users\losif\AppData\Local\Temp\ipykernel_43712\2436233452.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_test[column].fillna(df_test[column].mode()[0], inplace=True)

# %%
df_train["Electrical"].fillna(df_train["Electrical"].mode()[0], inplace = True)
# Out:
# C:\Users\losif\AppData\Local\Temp\ipykernel_43712\1304181753.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_train["Electrical"].fillna(df_train["Electrical"].mode()[0], inplace = True)

# %%
print(getMissingValues(df_train))
print(getMissingValues(df_test))
# Out:
# ([Series([], dtype: float64)], 0)
# ([Series([], dtype: float64)], 0)

# %%
df_train.to_csv("train_cleaned.csv" , index = False)

# %%
df_test.to_csv("test_cleaned.csv")

# %%
print(getMissingValues(df_train))
print(getMissingValues(df_test))
# Out:
# ([Series([], dtype: float64)], 0)
# ([Series([], dtype: float64)], 0)

# %%
df_train[df_train.select_dtypes(include = ["object","category"]).columns].nunique().sort_values(ascending = False)
# Out:
# Neighborhood     25
# Exterior2nd      16
# Exterior1st      15
# SaleType          9
# Condition1        9
# HouseStyle        8
# RoofMatl          8
# Condition2        8
# Functional        7
# Heating           6
# Foundation        6
# SaleCondition     6
# RoofStyle         6
# BsmtFinType1      6
# FireplaceQu       6
# GarageType        6
# BsmtFinType2      6
# Electrical        5
# GarageQual        5
# HeatingQC         5
# GarageCond        5
# MSZoning          5
# ExterCond         5
# BldgType          5
# LotConfig         5
# BsmtExposure      4
# BsmtCond          4
# KitchenQual       4
# ExterQual         4
# LandContour       4
# LotShape          4
# BsmtQual          4
# LandSlope         3
# GarageFinish      3
# PavedDrive        3
# Street            2
# CentralAir        2
# dtype: int64

# %%
print(df_train.shape)
mean_encoded = df_train.groupby('Neighborhood')['SalePrice'].mean()
df_train['Neighborhood'] = df_train['Neighborhood'].map(mean_encoded)


print(mean_encoded)
print(df_train.shape)
# Out:
# (1460, 75)
# Neighborhood
# Blmngtn    194870.882353
# Blueste    137500.000000
# BrDale     104493.750000
# BrkSide    124834.051724
# ClearCr    212565.428571
# CollgCr    197965.773333
# Crawfor    210624.725490
# Edwards    128219.700000
# Gilbert    192854.506329
# IDOTRR     100123.783784
# MeadowV     98576.470588
# Mitchel    156270.122449
# NAmes      145847.080000
# NPkVill    142694.444444
# NWAmes     189050.068493
# NoRidge    335295.317073
# NridgHt    316270.623377
# OldTown    128225.300885
# SWISU      142591.360000
# Sawyer     136793.135135
# SawyerW    186555.796610
# Somerst    225379.837209
# StoneBr    310499.000000
# Timber     242247.447368
# Veenker    238772.727273
# Name: SalePrice, dtype: float64
# (1460, 75)

# %%
df_train["Neighborhood"]
# Out:
# 0       197965.773333
# 1       238772.727273
# 2       197965.773333
# 3       210624.725490
# 4       335295.317073
#             ...
# 1455    192854.506329
# 1456    189050.068493
# 1457    210624.725490
# 1458    145847.080000
# 1459    128219.700000
# Name: Neighborhood, Length: 1460, dtype: float64

# %%
def encodeMean(CategoryColumn , Target):
    mean_encoded = df_train.groupby(CategoryColumn)[Target].mean()
    df_train[CategoryColumn] = df_train[CategoryColumn].map(mean_encoded)
    print(f"column {CategoryColumn} has been encoded with mean values of {Target}")

# %%
for i in df_train.select_dtypes(include = ["object","category"]).columns:
    encodeMean(i , "SalePrice" )
# Out:
# column MSZoning has been encoded with mean values of SalePrice
# column Street has been encoded with mean values of SalePrice
# column LotShape has been encoded with mean values of SalePrice
# column LandContour has been encoded with mean values of SalePrice
# column LotConfig has been encoded with mean values of SalePrice
# column LandSlope has been encoded with mean values of SalePrice
# column Condition1 has been encoded with mean values of SalePrice
# column Condition2 has been encoded with mean values of SalePrice
# column BldgType has been encoded with mean values of SalePrice
# column HouseStyle has been encoded with mean values of SalePrice
# column RoofStyle has been encoded with mean values of SalePrice
# column RoofMatl has been encoded with mean values of SalePrice
# column Exterior1st has been encoded with mean values of SalePrice
# column Exterior2nd has been encoded with mean values of SalePrice
# column ExterQual has been encoded with mean values of SalePrice
# ...

# %%
print(f"\033[92m""hend with n3na3")
# Out:
# hend with n3na3

# %%
# for i in df_test.select_dtypes(include = ["object","category"]).columns:
#     encodeMean(df_test, i , "SalePrice")

# %%
iiiii = df_test[df_test.select_dtypes(include = ["object","category"]).columns]
df_test.select_dtypes(include = ["object","category"]).columns
# Out:
# Index(['MSZoning', 'Street', 'LotShape', 'LandContour', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd',
#        'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond',
#        'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'Heating', 'HeatingQC',
#        'CentralAir', 'Electrical', 'KitchenQual', 'Functional', 'FireplaceQu',
#        'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond', 'PavedDrive',
#        'SaleType', 'SaleCondition'],
#       dtype='object')

# %%
sns.heatmap(df_train.corr(), cmap= "coolwarm")
# Out:
# <Axes: >

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
df_train_standardized = scaler.fit_transform(df_train)

# %%
g = sns.pairplot(df_train_standardized, markers="+")
g.map_lower(sns.boxplot)
g.map_upper(sns.boxplot)
g.map_diag (sns.boxplot)
g.add_legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[71], line 1
# ----> 1 g = sns.pairplot(df_train_standardized, markers="+")
#       2 g.map_lower(sns.boxplot)
#       3 g.map_upper(sns.boxplot)
#
# File d:\Python\Lib\site-packages\seaborn\axisgrid.py:2103, in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, corner, dropna, plot_kws, diag_kws, grid_kws, size)
#    2100     warnings.warn(msg, UserWarning)
#    2102 if not isinstance(data, pd.DataFrame):
# -> 2103     raise TypeError(
#    2104         f"'data' must be pandas DataFrame object, not: {type(data)}")
#    2106 plot_kws = {} if plot_kws is None else plot_kws.copy()
#    2107 diag_kws = {} if diag_kws is None else diag_kws.copy()
#
# TypeError: 'data' must be pandas DataFrame object, not: <class 'numpy.ndarray'>

# %%
print(df_train_standardized)
# Out:
# [[-1.73086488  0.07337496  0.38716428 ... -0.25554137 -0.1956359
#    0.34727322]
#  [-1.7284922  -0.87256276  0.38716428 ... -0.25554137 -0.1956359
#    0.00728832]
#  [-1.72611953  0.07337496  0.38716428 ... -0.25554137 -0.1956359
#    0.53615372]
#  ...
#  [ 1.72611953  0.30985939  0.38716428 ... -0.25554137 -0.1956359
#    1.07761115]
#  [ 1.7284922  -0.87256276  0.38716428 ... -0.25554137 -0.1956359
#   -0.48852299]
#  [ 1.73086488 -0.87256276  0.38716428 ... -0.25554137 -0.1956359
#   -0.42084081]]
